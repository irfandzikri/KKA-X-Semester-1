# %% [markdown]
# <a href="https://colab.research.google.com/github/irfandzikri/KKA-X-Semester-1/blob/main/App_bangun_bola_Shinta_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama kelompok: LELE TERBANG
#
# Nama panjang: Irfan dzikri
#
# Kelas: X.5
#
# No absen: 16

# %%
#program menghitung volume persegi panjang
π=(22/7)
r=float(input("masukkan jari jari bola(cm):"))
#menghitung volume bola
volume_bola=(4/3)*π*r**3
#menampilkan hasil
print(f"volume bola adalah:{volume_bola}cm")
