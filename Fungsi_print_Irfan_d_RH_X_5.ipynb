# %% [markdown]
# <a href="https://colab.research.google.com/github/irfandzikri/KKA-X-Semester-1/blob/main/Fungsi_print_Irfan_d_RH_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Menampilkan Teks Bebas

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("irfan dzikri")
# Out:
# irfan dzikri

# %% [markdown]
# #2. Menampilkan Nilai Variabel

# %%
beratbadan = 45
print(beratbadan)
# Out:
# 45

# %%
tinggibadan = 164
print(tinggibadan)
# Out:
# 164

# %%
Nama = "Irfan Dzikri"
print(Nama)
# Out:
# Irfan Dzikri

# %%
nama = "Muhammad Sulthan al fatih"
print(nama)
# Out:
# Muhammad Sulthan al fatih

# %%
print("Halo nama saya",Nama,". Berat badan saya",beratbadan,"kg.")
# Out:
# Halo nama saya Irfan Dzikri . Berat badan saya 45 kg.

# %%
print("Nama: Irfan dzikri")
print("kelas: X.5")
print("No Absen: 16")
# Out:
# Nama: Irfan dzikri
# kelas: X.5
# No Absen: 16

# %%
print("Halo nama saya"+Nama+". Berat badan saya"+str(beratbadan)+"kg.")
# Out:
# Halo nama sayaIrfan Dzikri. Berat badan saya45kg.

# %%
print("Nama: Irfan dzikri\nkelas: X.5\nNo. Absen: 16")
# Out:
# Nama: Irfan dzikri
# kelas: X.5
# No. Absen: 16

# %%
print("""Nama\t\t: Irfan dzikri
Kelas\t\t: X.5
No Absen\t: 16""")
# Out:
# Nama		: Irfan dzikri
# Kelas		: X.5
# No Absen	: 16

# %%
print('Nama saya Ja\'far Shodiq')
# Out:
# Nama saya Ja'far Shodiq

# %%
print("Nama saya Ja'far Shodiq")
# Out:
# Nama saya Ja'far Shodiq

# %%
print("Nama saya Ja\'far Shodiq")
# Out:
# Nama saya Ja'far Shodiq

# %%
print('Bu Shinta berkata, Tolong perhatikan TV dan Saya."')
# Out:
# Bu Shinta berkata, Tolong perhatikan TV dan Saya."

# %%
print("Bu Shinta berkata,\"Tolong perhatikan TV dan Saya.\"")
# Out:
# Bu Shinta berkata,"Tolong perhatikan TV dan Saya."

# %%
print("Lokasi file tugas KKA adalah  di Local disk C:\\KKA\\Tugas")
# Out:
# Lokasi file tugas KKA adalah  di Local disk C:\KKA\Tugas

# %%
nama_siswa_1 = "Jielo"
nama_siswa_2 = "Aida"
nama_siswa_3 = "Dani"
print(nama_siswa_1,end="-")
print(nama_siswa_2,end="-")
print(nama_siswa_3)
# Out:
# Jielo-Aida-Dani

# %%
print('''Bu Shinta berkata, "berikut adalah daftar piket harian kelas X.2
yang di simpan di file D:\\MAN Demak\\Jadwal Piket .".''')


print('nSenin\tSelasa\tRabu\nJelio\tHasbi\tNaufal\nAzam\tAida\tAinun')
# Out:
# Bu Shinta berkata, "berikut adalah daftar piket harian kelas X.2
# yang di simpan di file D:\MAN Demak\Jadwal Piket .".
# nSenin	Selasa	Rabu
# Jelio	Hasbi	Naufal
# Azam	Aida	Ainun

# %%
nama_siswa_1 = "Jileo"
nama_siswa_2 = "Aida"
nama_siswa_3 = "Dani"
nama_siswa_4 = "Nurul"

print(nama_siswa_1, nama_siswa_2, nama_siswa_3, nama_siswa_4, sep="/")
# Out:
# Jileo/Aida/Dani/Nurul

# %%
nama_siswa_5 = "Hasbi"
nama_siswa_6 = "Habibi"
nama_siswa_7 = "Rendra"
nama_siswa_8 = "Naufal"

print(nama_siswa_8, nama_siswa_7, nama_siswa_6, nama_siswa_5, sep="-")
# Out:
# Naufal-Rendra-Habibi-Hasbi

# %%
nama_siswa_5="Hasbi"
nama_siswa_6="Habibi"
nama_siswa_7="Rendra"
nama_siswa_8="Naufal"

print(nama_siswa_8, nama_siswa_7, nama_siswa_6, nama_siswa_5, sep="*")
# Out:
# Naufal*Rendra*Habibi*Hasbi

# %% [markdown]
# Jenis Tipe Variabel Pada Phyton

# %%
x = 17.5
print(x)
type(x)
# Out:
# 17.5
# float

# %%
y = 8
print(y)
type(y)
# Out:
# 8
# int

# %%
z = "shinta"
print(z)
type(z)
# Out:
# shinta
# str

# %%
p = True
print(p)
type(p)
# Out:
# True
# bool

# %%
r = -2.5
print(r)
type(r)
# Out:
# -2.5
# float

# %%
s = 5.1
print(s)
type(s)
# Out:
# 5.1
# float

# %%
k = '%7akh3'
print(k)
type(k)
# Out:
# %7akh3
# str

# %% [markdown]
# Mengubah Tipe Data

# %%
a = 25
print(a)
type(a)
# Out:
# 25
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 25.0
# float

# %%
a = str (a)
print(a)
type(a)
# Out:
# 25.0
# str

# %%
a = bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b = True
print(b)
type(b)
# Out:
# True
# bool

# %%
b = int(b)
print (b)
type(b)
# Out:
# 1
# int

# %%
b = float(b)
print(b)
type(b)
# Out:
# 1.0
# float

# %%
b = str(b)
print(b)
type(b)
# Out:
# 1.0
# str

# %%
c = False
print(c)
type(c)
# Out:
# False
# bool

# %%
c = float(c)
print(c)
type(c)
# Out:
# 0.0
# float

# %%
c = int(c)
print(c)
type(c)
# Out:
# 0
# int

# %%
c = str(c)
print(c)
type (c)
# Out:
# 0
# str

# %%
print(6>0)
# Out:
# True

# %%
print(7>9)
# Out:
# False

# %%
print(8<9)
# Out:
# True

# %%
print(8<4)
# Out:
# False

# %%
print(5>=5)
# Out:
# True

# %%
print(6>=5)
# Out:
# True

# %%
print(3==2)
# Out:
# False

# %%
print(3==3)
# Out:
# True

# %%
print(5!=5)
# Out:
# False

# %%
a= 8
b= 9
print(b<a)
# Out:
# False

# %%
print (b<8)
# Out:
# False

# %%
print(7 !=8 and 8>2)
# Out:
# True

# %%
print(7==8 and 8>2)
# Out:
# False

# %%
print(7==8 or 8>2)
# Out:
# True

# %%
print(not 7==8)
# Out:
# True

# %%
m = 10
n = 20
p = 30

print(m<n and p>m)
# Out:
# True
